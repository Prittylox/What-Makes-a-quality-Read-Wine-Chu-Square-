# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
redwine = pd.read_csv ("/Users/zoe/Desktop/Final Project /Please work Red1.csv")

# %%
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
redwine['fixed acidity'].corr(redwine['quality'])
# Out:
# 0.12405164911322428

# %%
redwine.corr(method='pearson')
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
redwine.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style type="text/css">
# #T_8e45e_row0_col0, #T_8e45e_row1_col1, #T_8e45e_row2_col2, #T_8e45e_row3_col3, #T_8e45e_row4_col4, #T_8e45e_row5_col5, #T_8e45e_row6_col6, #T_8e45e_row7_col7, #T_8e45e_row8_col8, #T_8e45e_row9_col9, #T_8e45e_row10_col10, #T_8e45e_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8e45e_row0_col1, #T_8e45e_row3_col5, #T_8e45e_row4_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_8e45e_row0_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_8e45e_row0_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_8e45e_row0_col4, #T_8e45e_row11_col9 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_8e45e_row0_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_8e45e_row0_col6, #T_8e45e_row6_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_8e45e_row0_col7 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# ...

# %%
sns.heatmap(redwine.corr(), annot=True)
# Out:
# <AxesSubplot:>
